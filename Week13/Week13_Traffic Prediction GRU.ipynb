# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Importing Libraries**

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# **Loading Data**

# %%
#Loading Data
data = pd.read_csv("drive/MyDrive/Keggle/traffic.csv")
data.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %% [markdown]
# **Data Exploration**

# %%
data["DateTime"]= pd.to_datetime(data["DateTime"])
data = data.drop(["ID"], axis=1) #dropping IDs
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %%
#df to be used for EDA
df=data.copy() 
#Let's plot the Timeseries
colors = [ "#FFD4DB","#BBE7FE","#D3B5E5","#dfe2b6"]
plt.figure(figsize=(20,4),facecolor="#627D78")
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Traffic On Junctions Over Years")
Time_series.set_ylabel("Number of Vehicles")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# **Feature Engineering**

# %%
#Exploring more features 
df["Year"]= df['DateTime'].dt.year
df["Month"]= df['DateTime'].dt.month
df["Date_no"]= df['DateTime'].dt.day
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Year  Month  Date_no  Hour     Day
# 0 2015-11-01 00:00:00         1        15  2015     11        1     0  Sunday
# 1 2015-11-01 01:00:00         1        13  2015     11        1     1  Sunday
# 2 2015-11-01 02:00:00         1        10  2015     11        1     2  Sunday
# 3 2015-11-01 03:00:00         1         7  2015     11        1     3  Sunday
# 4 2015-11-01 04:00:00         1         9  2015     11        1     4  Sunday

# %% [markdown]
# **Exploratory Data Analysis**

# %%
#Let's plot the Timeseries
new_features = [ "Year","Month", "Date_no", "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,2),facecolor="#627D78")
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=colors )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
plt.figure(figsize=(12,5),facecolor="#627D78")
count = sns.countplot(data=df, x =df["Year"], hue="Junction", palette=colors)
count.set_title("Count Of Traffic On Junctions Over Years")
count.set_ylabel("Number of Vehicles")
count.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
corrmat = df.corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )

# %%
sns.pairplot(data=df, hue= "Junction",palette=colors)

# %% [markdown]
# **Data Transformation And Preprocessing**

# %%
#Pivoting data fron junction 
df_J = data.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles
# Junction             1             2             3            4
# count     14592.000000  14592.000000  14592.000000  4344.000000
# mean         45.052906     14.253221     13.694010     7.251611
# std          23.008345      7.401307     10.436005     3.521455
# min           5.000000      1.000000      1.000000     1.000000
# 25%          27.000000      9.000000      7.000000     5.000000
# 50%          40.000000     13.000000     11.000000     7.000000
# 75%          59.000000     17.000000     18.000000     9.000000
# max         156.000000     48.000000    180.000000    36.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)   

#Function to plot comparitive plots of dataframes
def Sub_Plots4(df_1, df_2,df_3,df_4,title):
    fig, axes = plt.subplots(4, 1, figsize=(15, 8),facecolor="#627D78", sharey=True)
    fig.suptitle(title)
    #J1
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[0])
    #pl_1=plt.ylabel()
    axes[0].set(ylabel ="Junction 1")
    #J2
    pl_2=sns.lineplot(ax=axes[1],data=df_2,color=colors[1])
    axes[1].set(ylabel ="Junction 2")
    #J3
    pl_3=sns.lineplot(ax=axes[2],data=df_3,color=colors[2])
    axes[2].set(ylabel ="Junction 3")
    #J4
    pl_4=sns.lineplot(ax=axes[3],data=df_4,color=colors[3])
    axes[3].set(ylabel ="Junction 4")
    
    
#Plotting the dataframe to check for stationarity
Sub_Plots4(df_1.Vehicles, df_2.Vehicles,df_3.Vehicles,df_4.Vehicles,"Dataframes Before Transformation")

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %%
Sub_Plots4(df_N1.Diff, df_N2.Diff,df_N3.Diff,df_N4.Diff,"Dataframes After Transformation")

# %%
#Stationary Check for the time series Augmented Dickey Fuller test
def Stationary_check(df):
    check = adfuller(df.dropna())
    print(f"ADF Statistic: {check[0]}")
    print(f"p-value: {check[1]}")
    print("Critical Values:")
    for key, value in check[4].items():
        print('\t%s: %.3f' % (key, value))
    if check[0] > check[4]["1%"]:
        print("Time Series is Non-Stationary")
    else:
        print("Time Series is Stationary") 
  

#Checking if the series is stationary

List_df_ND = [ df_N1["Diff"], df_N2["Diff"], df_N3["Diff"], df_N4["Diff"]] 
print("Checking the transformed series for stationarity:")
for i in List_df_ND:
    print("\n")
    Stationary_check(i)
# Out:
# Checking the transformed series for stationarity:
#
#
# ADF Statistic: -15.265303390415456
# p-value: 4.798539876396407e-28
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -21.795891026940122
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -28.001759908832987
# p-value: 0.0
# Critical Values:
# 	1%: -3.431
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary
#
#
# ADF Statistic: -17.97909256305222
# p-value: 2.77878753259558e-30
# Critical Values:
# 	1%: -3.432
# 	5%: -2.862
# 	10%: -2.567
# Time Series is Stationary

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %% [markdown]
# **Model Building**

# %%
#Model for the prediction
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) 
    #callback delta 0.01 may interrupt the learning, could eliminate this step, but meh!
    
    #The GRU model 
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    #model.add(GRU(units=50, return_sequences=True,  input_shape=(X_Train.shape[1],1),activation='tanh'))
    #model.add(Dropout(0.2))
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
    #Compiling the model
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#To calculate the root mean squred error in predictions
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5),facecolor="#627D78")
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("GRU Traffic Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %% [markdown]
# **Fitting The Model**

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 41s 370ms/step - loss: 0.0811
# Epoch 2/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0661WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0661
# Epoch 3/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0642
# Epoch 4/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0635WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0635
# Epoch 5/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0612WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 372ms/step - loss: 0.0612
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0599WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 373ms/step - loss: 0.0599
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0596WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0596
# Epoch 8/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0583WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0583
# Epoch 9/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0579WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 372ms/step - loss: 0.0579
# Epoch 10/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0569WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 373ms/step - loss: 0.0569
# Epoch 11/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0564WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 373ms/step - loss: 0.0564
# Epoch 12/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0555WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 375ms/step - loss: 0.0555
# Epoch 13/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0553WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 374ms/step - loss: 0.0553
# Epoch 14/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0541WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 33s 374ms/step - loss: 0.0541
# Epoch 15/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0540WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 372ms/step - loss: 0.0540
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0533WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0533
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0533WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0533
# Epoch 18/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0523
# Epoch 19/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0526WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0526
# Epoch 20/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0515
# Epoch 21/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0512WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0512
# Epoch 22/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0511WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0511
# Epoch 23/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0510WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0510
# Epoch 24/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0509WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0509
# Epoch 25/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0505
# Epoch 26/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0507WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0507
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 368ms/step - loss: 0.0499
# Epoch 28/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0502WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 368ms/step - loss: 0.0502
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0503WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0503
# Epoch 30/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0501WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0501
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0495
# Epoch 32/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0496
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0493
# Epoch 34/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0494WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0494
# Epoch 35/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0494WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 368ms/step - loss: 0.0494
# Epoch 36/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0494WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0494
# Epoch 37/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0490WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0490
# Epoch 38/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0493
# Epoch 39/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0491WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 368ms/step - loss: 0.0491
# Epoch 40/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 368ms/step - loss: 0.0486
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0485WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 372ms/step - loss: 0.0485
# Epoch 42/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0479
# Epoch 43/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0485WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0485
# Epoch 44/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0484
# Epoch 45/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0478
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0480
# Epoch 47/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0478
# Epoch 48/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 369ms/step - loss: 0.0482
# Epoch 49/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 370ms/step - loss: 0.0481
# Epoch 50/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 32s 371ms/step - loss: 0.0477

# %%
#Results for J1 
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.24617733601909175.

# %%
#Predictions For Second Junction
PredJ2 = GRU_model(X_trainJ2,y_trainJ2,X_testJ2)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2355WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 42s 372ms/step - loss: 0.2355
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2060WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2060
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1962WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1962
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1931WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.1931
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1923WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1923
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1929WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1929
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1922WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1922
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1892
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1897
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1894WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1894
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1877WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 370ms/step - loss: 0.1877
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1880
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1869
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 371ms/step - loss: 0.1862
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1867WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1867
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1870WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1870
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.1856
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1850
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1849
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1857
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1857
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.1849
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1850
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1843WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1843
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1846WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1846
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1848WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1848
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1830
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1841WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1841
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1833
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1826
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1830
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1828
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1821
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1830
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1837WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1837
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1829WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1829
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1823WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1823
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1831WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1831
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1821WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1821
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1830WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1830
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1812
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1824
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 373ms/step - loss: 0.1828
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1801
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1816
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1819WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1819
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1803WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1803
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1811WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.1811
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1804WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.1804
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.1816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.1816

# %%
#Results for J2
RMSE_J2=RMSE_Value(y_testJ2,PredJ2)
PredictionsPlot(y_testJ2,PredJ2,1)
# Out:
# The root mean squared error is 0.5617617992903711.

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 88/88 [==============================] - ETA: 0s - loss: 0.3019WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 43s 382ms/step - loss: 0.3019
# Epoch 2/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2957WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2957
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2947WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2947
# Epoch 4/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2929WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.2929
# Epoch 5/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2892
# Epoch 6/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2879WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2879
# Epoch 7/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2867WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2867
# Epoch 8/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2896
# Epoch 9/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2896WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2896
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2880
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2866WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 380ms/step - loss: 0.2866
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2857WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2857
# Epoch 13/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2893WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2893
# Epoch 14/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2860
# Epoch 15/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2828
# Epoch 16/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2845WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2845
# Epoch 17/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2812
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 380ms/step - loss: 0.2818
# Epoch 19/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2807WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2807
# Epoch 20/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2768WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2768
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2799WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.2799
# Epoch 22/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2763WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2763
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2750WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2750
# Epoch 24/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2754WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.2754
# Epoch 25/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2729WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.2729
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2703WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2703
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2755WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.2755
# Epoch 28/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2752WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2752
# Epoch 29/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2714WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 380ms/step - loss: 0.2714
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2718
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2698WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 380ms/step - loss: 0.2698
# Epoch 32/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2757WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 378ms/step - loss: 0.2757
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2702WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2702
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2702WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2702
# Epoch 35/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2686WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.2686
# Epoch 36/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2690
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2683WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2683
# Epoch 38/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2670WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 379ms/step - loss: 0.2670
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2685WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 388ms/step - loss: 0.2685
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2651WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2651
# Epoch 41/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2704WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.2704
# Epoch 42/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2669WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2669
# Epoch 43/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 376ms/step - loss: 0.2637
# Epoch 44/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2663WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 374ms/step - loss: 0.2663
# Epoch 45/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2640WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2640
# Epoch 46/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2654WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 34s 382ms/step - loss: 0.2654
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2624WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 377ms/step - loss: 0.2624
# Epoch 48/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 375ms/step - loss: 0.2644
# Epoch 49/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2626WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2626
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 33s 372ms/step - loss: 0.2658

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6080788231069989.

# %%
#Predictions For Forth Junction
PredJ4 = GRU_model(X_trainJ4,y_trainJ4,X_testJ4)
# Out:
# Epoch 1/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 19s 372ms/step - loss: 0.6916
# Epoch 2/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6915WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6915
# Epoch 3/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6868
# Epoch 4/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6880WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6880
# Epoch 5/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 375ms/step - loss: 0.6862
# Epoch 6/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 368ms/step - loss: 0.6816
# Epoch 7/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6792WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6792
# Epoch 8/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6805WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6805
# Epoch 9/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6809WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6809
# Epoch 10/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6770WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6770
# Epoch 11/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6795
# Epoch 12/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6784WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6784
# Epoch 13/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6794WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6794
# Epoch 14/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6833WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6833
# Epoch 15/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6774WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6774
# Epoch 16/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6743WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 369ms/step - loss: 0.6743
# Epoch 17/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6764WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6764
# Epoch 18/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6734WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6734
# Epoch 19/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6759WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6759
# Epoch 20/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6708WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6708
# Epoch 21/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6739WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6739
# Epoch 22/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6744WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 374ms/step - loss: 0.6744
# Epoch 23/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6687WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6687
# Epoch 24/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6755WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 373ms/step - loss: 0.6755
# Epoch 25/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6692
# Epoch 26/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6645WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6645
# Epoch 27/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6691WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 369ms/step - loss: 0.6691
# Epoch 28/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6639WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6639
# Epoch 29/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6577WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6577
# Epoch 30/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6585WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6585
# Epoch 31/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6544WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6544
# Epoch 32/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6556WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6556
# Epoch 33/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6456WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.6456
# Epoch 34/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6388WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6388
# Epoch 35/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6247WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6247
# Epoch 36/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6268WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 373ms/step - loss: 0.6268
# Epoch 37/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6136WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 375ms/step - loss: 0.6136
# Epoch 38/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6167WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.6167
# Epoch 39/50
# 26/26 [==============================] - ETA: 0s - loss: 0.6215WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.6215
# Epoch 40/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 373ms/step - loss: 0.5899
# Epoch 41/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5939WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 370ms/step - loss: 0.5939
# Epoch 42/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5849WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.5849
# Epoch 43/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.5897
# Epoch 44/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.5718
# Epoch 45/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5728WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 373ms/step - loss: 0.5728
# Epoch 46/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5518WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 371ms/step - loss: 0.5518
# Epoch 47/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5387WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.5387
# Epoch 48/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5372WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.5372
# Epoch 49/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 372ms/step - loss: 0.5438
# Epoch 50/50
# 26/26 [==============================] - ETA: 0s - loss: 0.5290WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 26/26 [==============================] - 10s 374ms/step - loss: 0.5290

# %%
#Results for J4
RMSE_J4=RMSE_Value(y_testJ4,PredJ4)
PredictionsPlot(y_testJ4,PredJ4,3)
# Out:
# The root mean squared error is 0.9952384046579763.

# %% [markdown]
# **Inversing The Transformation Of Data**

# %%
# Functions to inverse transforms and Plot comparitive plots
# invert differenced forecast
def inverse_difference(last_ob, value):
    inversed = value + last_ob
    return inversed
#Plotting the comparison
def Sub_Plots2(df_1, df_2,title,m):
    fig, axes = plt.subplots(1, 2, figsize=(18,4), sharey=True,facecolor="#627D78")
    fig.suptitle(title)
    
    pl_1=sns.lineplot(ax=axes[0],data=df_1,color=colors[m])
    axes[0].set(ylabel ="Prediction")
    
    pl_2=sns.lineplot(ax=axes[1],data=df_2["Vehicles"],color="#627D78")
    axes[1].set(ylabel ="Orignal")

# %%
# invert the differenced forecast for Junction 1 
recover1 = df_N1.Norm[-1412:-1].to_frame()
recover1["Pred"]= PredJ1
Transform_reverssed_J1 = inverse_difference(recover1.Norm, recover1.Pred).to_frame()
Transform_reverssed_J1.columns = ["Pred_Normed"]
#Invert the normalizeation J1
Final_J1_Pred = (Transform_reverssed_J1.values* std_J1) + av_J1
Transform_reverssed_J1["Pred_Final"] =Final_J1_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J1["Pred_Final"], df_1[-1412:-1],"Pridictions And Orignals For Junction 1", 0)

# %%
#Invert the differenced J2
recover2 = df_N2.Norm[-1426:-1].to_frame() #len as per the diff
recover2["Pred"]= PredJ2
Transform_reverssed_J2 = inverse_difference(recover2.Norm, recover2.Pred).to_frame()
Transform_reverssed_J2.columns = ["Pred_Normed"]
Final_J2_Pred = (Transform_reverssed_J2.values* std_J2) + av_J2
Transform_reverssed_J2["Pred_Final"] =Final_J2_Pred
#Plotting the Predictions with orignals 
Sub_Plots2(Transform_reverssed_J2["Pred_Final"], df_2[-1426:-1],"Pridictions And Orignals For Junction 2", 1)

# %%
#Invert the differenced J3
recover3 = df_N3.Norm[-1429:-1].to_frame() #len as per the diff
recover3["Pred"]= PredJ3
Transform_reverssed_J3 = inverse_difference(recover3.Norm, recover3.Pred).to_frame()
Transform_reverssed_J3.columns = ["Pred_Normed"]
#Invert the normalizeation J3
Final_J3_Pred = (Transform_reverssed_J3.values* std_J3) + av_J3
Transform_reverssed_J3["Pred_Final"] =Final_J3_Pred
Sub_Plots2(Transform_reverssed_J3["Pred_Final"], df_3[-1429:-1],"Pridictions And Orignals For Junction 3", 2)

# %%
#Invert the differenced J4
recover4 = df_N4.Norm[-404:-1].to_frame()  #len as per the testset
recover4["Pred"]= PredJ4
Transform_reverssed_J4 = inverse_difference(recover4.Norm, recover4.Pred).to_frame()
Transform_reverssed_J4.columns = ["Pred_Normed"]
#Invert the normalizeation J4
Final_J4_Pred = (Transform_reverssed_J4.values* std_J4) + av_J4
Transform_reverssed_J4["Pred_Final"] =Final_J4_Pred
Sub_Plots2(Transform_reverssed_J4["Pred_Final"], df_4[-404:-1],"Pridictions And Orignals For Junction 4", 3)
